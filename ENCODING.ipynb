# %%
\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\import numpy as np
import pandas as pd

# %%
df = pd.read_csv('customer.csv')
df.head(5)
df
# Out:
#     age  gender   review education     island purchased
# 0    30  Female  Average    School     Biscoe        No
# 1    68  Female     Poor        UG      Dream        No
# 2    70  Female     Good        PG  Torgersen        No
# 3    72  Female     Good        PG     Biscoe        No
# 4    16  Female  Average        UG      Dream        No
# 5    31  Female  Average    School  Torgersen       Yes
# 6    18    Male     Good    School        NaN        No
# 7    60  Female     Poor    School     Biscoe       Yes
# 8    65  Female  Average        UG      Dream        No
# 9    74    Male     Good        UG  Torgersen       Yes
# 10   98  Female     Good        UG      Dream       Yes
# 11   74    Male     Good        UG  Torgersen       Yes
# 12   51    Male     Poor    School  Torgersen        No
# 13   57  Female  Average    School      Dream        No
# 14   15    Male     Poor        PG  Torgersen       Yes
# 15   75    Male     Poor        UG     Biscoe        No
# ...

# %%
df = df.iloc[:,2:]
df
# Out:
#      review education     island purchased
# 0   Average    School     Biscoe        No
# 1      Poor        UG      Dream        No
# 2      Good        PG  Torgersen        No
# 3      Good        PG     Biscoe        No
# 4   Average        UG      Dream        No
# 5   Average    School  Torgersen       Yes
# 6      Good    School        NaN        No
# 7      Poor    School     Biscoe       Yes
# 8   Average        UG      Dream        No
# 9      Good        UG  Torgersen       Yes
# 10     Good        UG      Dream       Yes
# 11     Good        UG  Torgersen       Yes
# 12     Poor    School  Torgersen        No
# 13  Average    School      Dream        No
# 14     Poor        PG  Torgersen       Yes
# 15     Poor        UG     Biscoe        No
# 16     Poor        UG      Dream       Yes
# 17     Poor        UG  Torgersen       Yes
# 18     Good    School      Dream        No
# 19     Poor        PG  Torgersen       Yes
# 20  Average    School      Dream       Yes
# ...

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('customer.csv')
from sklearn import preprocessing

# %%
my_label=preprocessing.LabelEncoder()
df['purchased']=my_label.fit_transform(df['purchased'])
print(df)

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])
df[['review','education']]=oe.fit_transform(df[['review','education']])
print(df)

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])
df[['review','education']]=oe.fit_transform(df[['review','education']])
print(df)

# %%
pd.get_dummies(df,columns=['gender'],drop_first=True)

# %%
from sklearn.preprocessing import OneHotEncoder
from seaborn import load_dataset
import numpy as np
from sklearn.preprocessing import OneHotEncoder
oe = OneHotEncoder(handle_unknown='ignore')
#oe = OneHotEncoder(categories=['island'])
#df['island']=oe.fit_transform(df['island'])
x=pd.DataFrame(oe.fit_transform(df[['island']]).toarray())
# merge with main df bridge_df on key values
bridge_df =x.join(df)
print(bridge_df)
#print(df)
# Out:
#       0    1    2    3  age  gender   review education     island purchased
# 0   1.0  0.0  0.0  0.0   30  Female  Average    School     Biscoe        No
# 1   0.0  1.0  0.0  0.0   68  Female     Poor        UG      Dream        No
# 2   0.0  0.0  1.0  0.0   70  Female     Good        PG  Torgersen        No
# 3   1.0  0.0  0.0  0.0   72  Female     Good        PG     Biscoe        No
# 4   0.0  1.0  0.0  0.0   16  Female  Average        UG      Dream        No
# 5   0.0  0.0  1.0  0.0   31  Female  Average    School  Torgersen       Yes
# 6   0.0  0.0  0.0  1.0   18    Male     Good    School        NaN        No
# 7   1.0  0.0  0.0  0.0   60  Female     Poor    School     Biscoe       Yes
# 8   0.0  1.0  0.0  0.0   65  Female  Average        UG      Dream        No
# 9   0.0  0.0  1.0  0.0   74    Male     Good        UG  Torgersen       Yes
# 10  0.0  1.0  0.0  0.0   98  Female     Good        UG      Dream       Yes
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
from seaborn import load_dataset
import numpy as np
df = load_dataset('penguins')
df

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore')
x=pd.DataFrame(enc.fit_transform(df[['island']]).toarray())
# merge with main df bridge_df on key values
bridge_df =x.join(df)
bridge_df
# Out:
#        0    1    2 species     island  bill_length_mm  bill_depth_mm  \
# 0    0.0  0.0  1.0  Adelie  Torgersen            39.1           18.7
# 1    0.0  0.0  1.0  Adelie  Torgersen            39.5           17.4
# 2    0.0  0.0  1.0  Adelie  Torgersen            40.3           18.0
# 3    0.0  0.0  1.0  Adelie  Torgersen             NaN            NaN
# 4    0.0  0.0  1.0  Adelie  Torgersen            36.7           19.3
# ..   ...  ...  ...     ...        ...             ...            ...
# 339  1.0  0.0  0.0  Gentoo     Biscoe             NaN            NaN
# 340  1.0  0.0  0.0  Gentoo     Biscoe            46.8           14.3
# 341  1.0  0.0  0.0  Gentoo     Biscoe            50.4           15.7
# 342  1.0  0.0  0.0  Gentoo     Biscoe            45.2           14.8
# 343  1.0  0.0  0.0  Gentoo     Biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g     sex
# 0                181.0       3750.0    Male
# 1                186.0       3800.0  Female
# ...

# %%
x_train

# %%
y_train

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('customer.csv')
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test= train_test_split(df.iloc[:,2:4],df.iloc[:,-1],test_size= 0.2)

# %%
oe = OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])

# %%
oe.fit(x_train)
# Out:
# OrdinalEncoder(categories=[['Poor', 'Average', 'Good'], ['School', 'UG', 'PG']])

# %%
x_train = oe.transform(x_train)

# %%
x_train

# %%
oe.categories_
# Out:
# [array(['Poor', 'Average', 'Good'], dtype=object),
#  array(['School', 'UG', 'PG'], dtype=object)]

# %%
x_train

# %%
import pandas as pd
from sklearn import preprocessing
my_data={
"Gender":['F','M','M','F','M','F','M','F','F','M'],
"Name":['Shweta','Rohit','Abhay','Surbhi','Amit','Sara','Vicky','Mehak','Sita','Saurabh']}
blk=pd.DataFrame(my_data)
print(blk)
my_label=preprocessing.LabelEncoder()
blk['Gender']=my_label.fit_transform(blk['Gender'])
print(blk['Gender'].unique())
print("DataFrameafterLabelEncoding:\n")
print(blk)

# %%
import pandas as pd
from sklearn import preprocessing
df = pd.read_csv('customer.csv')
blk=pd.DataFrame(df)
print(blk)
my_label=preprocessing.LabelEncoder()
blk['purchased']=my_label.fit_transform(blk['purchased'])
print(blk['purchased'].unique())
print("DataFrameafterLabelEncoding:\n")
print(blk)

# %%
import pandas as pd
df = pd.read_csv('customer.csv')

# %%
df.head()

# %%
df['gender'].value_counts()
# Out:
# Female    29
# Male      21
# Name: gender, dtype: int64

# %%
pd.get_dummies(df,columns=['gender'])

# %%
counts = df['island'].value_counts()
counts

# %%
ohe = OneHotEncoder()
transformed =pd.DataFrame(ohe.fit_transform(df[['island']]).toarray())
new_df=df.join(transformed)
print(new_df)

# %%
ohe = OneHotEncoder()
transformed =pd.DataFrame(ohe.fit_transform(df[['island']]).toarray())
new_df=df.join(transformed)
print(new_df)
